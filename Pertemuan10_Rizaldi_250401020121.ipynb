# %% [markdown]
# **Rizaldi** **250401020121** **IF405**

# %% [markdown]
# **Langkah 1: Muat dan Eksplorasi Data**

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("telco_churn.csv")
print(df.shape)
print(df["Churn"].value_counts(normalize=True))
# Out:
# (7043, 21)
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %% [markdown]
# **Langkah 2: Preprocessing**

# %%
from sklearn.model_selection import train_test_split
# TODO: pisahkan X (fitur) dan y (target = Churn)
# Sembari memisahkan, kita bersihkan string kosong di TotalCharges agar tidak error
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'].replace(' ', '0'))

X = df.drop(columns=['customerID', 'Churn'])
y = df['Churn'].map({'Yes': 1, 'No': 0})

# TODO: encoding fitur kategorikal (mis. pd.get_dummies)
X = pd.get_dummies(X, drop_first=True)


X_tr, X_te, y_tr, y_te = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %% [markdown]
# **Langkah 3: Latih Model**

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(
    n_estimators=300, class_weight="balanced", random_state=42
)
rf.fit(X_tr, y_tr)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=300,
#                        random_state=42)

# %% [markdown]
# **Langkah 4: Evaluasi**

# %%
from sklearn.metrics import classification_report, roc_auc_score
# TODO: hitung prediksi dan probabilitas
y_pred = rf.predict(X_te)
y_prob = rf.predict_proba(X_te)[:, 1]

# TODO: tampilkan classification_report dan ROC-AUC
print("\n=== Langkah 4: Evaluasi Model ===")
print("\nClassification Report:")
print(classification_report(y_te, y_pred))
print(f"ROC-AUC Score: {roc_auc_score(y_te, y_prob):.4f}")
# Out:
# === Langkah 4: Evaluasi Model ===
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1035
#            1       0.63      0.49      0.56       374
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.70      0.71      1409
# weighted avg       0.78      0.79      0.78      1409
#
# ROC-AUC Score: 0.8260

# %% [markdown]
# **Langkah 5: Prediksi Probabilitas dan Simpulkan**

# %%
# TODO: hitung probabilitas churn (predict_proba)
probabilitas_churn = rf.predict_proba(X_te)[:, 1]

print("\n=== Langkah 5: Kesimpulan ===")
# TODO: tulis kesimpulan singkat (3-4 kalimat)
kesimpulan = (
    "Dataset terbukti imbalanced dengan rasio pelanggan tidak churn mencapai 73.46%, "
    "sedangkan yang churn hanya 26.54%. Parameter class_weight='balanced' membantu model "
    "mencapai performa pemisahan kelas yang baik dengan skor ROC-AUC sebesar 0.8260. "
    "Meskipun begitu, nilai recall untuk mendeteksi pelanggan churn (kelas 1) masih berada di "
    "angka 0.49, yang mengindikasikan model masih melewatkan sekitar 51% pelanggan yang "
    "sebenarnya berpotensi churn."
)
print(kesimpulan)
# Out:
# === Langkah 5: Kesimpulan ===
# Dataset terbukti imbalanced dengan rasio pelanggan tidak churn mencapai 73.46%, sedangkan yang churn hanya 26.54%. Parameter class_weight='balanced' membantu model mencapai performa pemisahan kelas yang baik dengan skor ROC-AUC sebesar 0.8260. Meskipun begitu, nilai recall untuk mendeteksi pelanggan churn (kelas 1) masih berada di angka 0.49, yang mengindikasikan model masih melewatkan sekitar 51% pelanggan yang sebenarnya berpotensi churn.

# %% [markdown]
# ### **Kesimpulan**
#
# * **Apa yang Dipelajari**:
#   * Teknik penanganan dataset yang tidak seimbang (*imbalanced dataset*) menggunakan parameter `class_weight='balanced'`.
#   * Penerapan algoritma *Random Forest Classifier* untuk klasifikasi *churn* pelanggan.
#   * Evaluasi performa model menggunakan *Classification Report* dan *ROC-AUC Score*.
#
# * **Temuan Utama**:
#   * Model berhasil mencapai skor **ROC-AUC sebesar 0.8260**, yang menunjukkan kemampuan pemisahan kelas yang baik secara keseluruhan.
#
# * **Keterbatasan**:
#   * *Keterbatasan*: Masih tingginya angka *false negatives* menunjukkan model belum optimal dalam mendeteksi seluruh pelanggan yang akan berhenti berlangganan.
